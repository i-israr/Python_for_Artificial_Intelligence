# %% [markdown]
# # # Data Wragling (Joining)
#
# > df.merge()
# > df.join()
# > pd.concat()
#
# # Group by
# # Handling Missing Values

# %%
import numpy as np
import pandas as pd

# %%
df1 = pd.DataFrame({"CNIC": np.random.randint(1,20, size=20),
                   "Account No":np.random.randint(1,5, size=(20))})

df1
#12345-1234567-3
#1234512345673
# Out:
#     Account No  CNIC
# 0            2     6
# 1            2     9
# 2            2    11
# 3            4    18
# 4            3    14
# 5            4    18
# 6            2     7
# 7            2     6
# 8            2    17
# 9            1    11
# 10           4     2
# 11           4    16
# 12           4     9
# 13           4    13
# 14           2    14
# 15           3    14
# 16           2     6
# 17           1    19
# 18           2    13
# 19           2     2

# %%
df2 = pd.DataFrame({"CNIC": np.random.randint(1,20, size=(20)),
                   "Account No":np.random.randint(1,5, size=(20)),
                   "Mobile No":np.random.randint(2001,3000, size=(20)),
                  "DOB":pd.date_range('1990-01-01', periods=20, freq="M"),
                  "CustomerName":[chr(x) for x in np.random.randint(65,91, size=(20))],
                   "Gender":np.random.choice(["M","F"], size=(20))})
df2
# Out:
#     Account No  CNIC CustomerName        DOB Gender  Mobile No
# 0            1    19            X 1990-01-31      M       2812
# 1            4    15            B 1990-02-28      M       2414
# 2            4    14            T 1990-03-31      M       2732
# 3            3    16            A 1990-04-30      F       2425
# 4            4    13            Y 1990-05-31      M       2281
# 5            2    18            I 1990-06-30      M       2591
# 6            1     3            A 1990-07-31      F       2557
# 7            4    19            W 1990-08-31      F       2255
# 8            2    13            N 1990-09-30      F       2421
# 9            2    19            D 1990-10-31      F       2621
# 10           1    15            T 1990-11-30      M       2979
# 11           4     2            J 1990-12-31      M       2690
# 12           2    19            V 1991-01-31      F       2816
# 13           1     9            H 1991-02-28      M       2901
# 14           2    13            P 1991-03-31      M       2391
# 15           1     8            B 1991-04-30      M       2013
# 16           3    16            R 1991-05-31      M       2029
# 17           2     5            C 1991-06-30      F       2472
# 18           1     7            K 1991-07-31      F       2494
# 19           4     6            B 1991-08-31      F       2320

# %%
#data_frame_left.merge(dataframe_right, on="columnNameSameInBothDataframes", how="typeofJoin")
#typeofJoin=inner,outer,left,right

#data_frame_left.merge(dataframe_right, on=[col1,col2,col3], how="typeofJoin")

#data_frame_left.merge(dataframe_right, on=[col1,col2,col3], how="typeofJoin")

#if columns name differents in both table 

#data_frame_left.merge(dataframe_right, left_on="col", right_on="col", how="typeofJoin")

#data_frame_left.merge(dataframe_right, left_index=True, right_index=True, how='outer')

print(df1.dtypes, df2.dtypes, sep="\n\n\n")
# Out:
# Account No    int32
# CNIC          int32
# dtype: object
#
#
# Account No               int32
# CNIC                     int32
# CustomerName            object
# DOB             datetime64[ns]
# Gender                  object
# Mobile No                int32
# dtype: object

# %%
#data_frame_left.merge(dataframe_right, on="columnNameSameInBothDataframes", how="typeofJoin")
a = df1.merge(df2, on="CNIC", how="inner")
a
# Out:
#     Account No_x  CNIC  Account No_y CustomerName        DOB Gender  Mobile No
# 0              2     6             4            B 1991-08-31      F       2320
# 1              2     6             4            B 1991-08-31      F       2320
# 2              2     6             4            B 1991-08-31      F       2320
# 3              2     9             1            H 1991-02-28      M       2901
# 4              4     9             1            H 1991-02-28      M       2901
# 5              4    18             2            I 1990-06-30      M       2591
# 6              4    18             2            I 1990-06-30      M       2591
# 7              3    14             4            T 1990-03-31      M       2732
# 8              2    14             4            T 1990-03-31      M       2732
# 9              3    14             4            T 1990-03-31      M       2732
# 10             2     7             1            K 1991-07-31      F       2494
# 11             4     2             4            J 1990-12-31      M       2690
# 12             2     2             4            J 1990-12-31      M       2690
# 13             4    16             3            A 1990-04-30      F       2425
# 14             4    16             3            R 1991-05-31      M       2029
# 15             4    13             4            Y 1990-05-31      M       2281
# 16             4    13             2            N 1990-09-30      F       2421
# 17             4    13             2            P 1991-03-31      M       2391
# 18             2    13             4            Y 1990-05-31      M       2281
# 19             2    13             2            N 1990-09-30      F       2421
# 20             2    13             2            P 1991-03-31      M       2391
# 21             1    19             1            X 1990-01-31      M       2812
# 22             1    19             4            W 1990-08-31      F       2255
# 23             1    19             2            D 1990-10-31      F       2621
# 24             1    19             2            V 1991-01-31      F       2816

# %%
#data_frame_left.merge(dataframe_right, on=[col1,col2,col3], how="typeofJoin")
a = df1.merge(df2, on=["CNIC","Account No"], how="inner")
a
# Out:
#    Account No  CNIC CustomerName        DOB Gender  Mobile No
# 0           4     2            J 1990-12-31      M       2690
# 1           4    13            Y 1990-05-31      M       2281
# 2           1    19            X 1990-01-31      M       2812
# 3           2    13            N 1990-09-30      F       2421
# 4           2    13            P 1991-03-31      M       2391

# %%
a = df1.merge(df2, on=["CNIC","Account No"], how="left")
a
# Out:
#     Account No  CNIC CustomerName        DOB Gender  Mobile No
# 0            2     6          NaN        NaT    NaN        NaN
# 1            2     9          NaN        NaT    NaN        NaN
# 2            2    11          NaN        NaT    NaN        NaN
# 3            4    18          NaN        NaT    NaN        NaN
# 4            3    14          NaN        NaT    NaN        NaN
# 5            4    18          NaN        NaT    NaN        NaN
# 6            2     7          NaN        NaT    NaN        NaN
# 7            2     6          NaN        NaT    NaN        NaN
# 8            2    17          NaN        NaT    NaN        NaN
# 9            1    11          NaN        NaT    NaN        NaN
# 10           4     2            J 1990-12-31      M     2690.0
# 11           4    16          NaN        NaT    NaN        NaN
# 12           4     9          NaN        NaT    NaN        NaN
# 13           4    13            Y 1990-05-31      M     2281.0
# 14           2    14          NaN        NaT    NaN        NaN
# 15           3    14          NaN        NaT    NaN        NaN
# 16           2     6          NaN        NaT    NaN        NaN
# 17           1    19            X 1990-01-31      M     2812.0
# 18           2    13            N 1990-09-30      F     2421.0
# 19           2    13            P 1991-03-31      M     2391.0
# 20           2     2          NaN        NaT    NaN        NaN

# %%
a = df1.merge(df2, on=["CNIC","Account No"], how="outer")
a
# Out:
#     Account No  CNIC CustomerName        DOB Gender  Mobile No
# 0            2     6          NaN        NaT    NaN        NaN
# 1            2     6          NaN        NaT    NaN        NaN
# 2            2     6          NaN        NaT    NaN        NaN
# 3            2     9          NaN        NaT    NaN        NaN
# 4            2    11          NaN        NaT    NaN        NaN
# 5            4    18          NaN        NaT    NaN        NaN
# 6            4    18          NaN        NaT    NaN        NaN
# 7            3    14          NaN        NaT    NaN        NaN
# 8            3    14          NaN        NaT    NaN        NaN
# 9            2     7          NaN        NaT    NaN        NaN
# 10           2    17          NaN        NaT    NaN        NaN
# 11           1    11          NaN        NaT    NaN        NaN
# 12           4     2            J 1990-12-31      M     2690.0
# 13           4    16          NaN        NaT    NaN        NaN
# 14           4     9          NaN        NaT    NaN        NaN
# 15           4    13            Y 1990-05-31      M     2281.0
# 16           2    14          NaN        NaT    NaN        NaN
# 17           1    19            X 1990-01-31      M     2812.0
# 18           2    13            N 1990-09-30      F     2421.0
# 19           2    13            P 1991-03-31      M     2391.0
# 20           2     2          NaN        NaT    NaN        NaN
# 21           4    15            B 1990-02-28      M     2414.0
# 22           4    14            T 1990-03-31      M     2732.0
# 23           3    16            A 1990-04-30      F     2425.0
# 24           3    16            R 1991-05-31      M     2029.0
# 25           2    18            I 1990-06-30      M     2591.0
# 26           1     3            A 1990-07-31      F     2557.0
# 27           4    19            W 1990-08-31      F     2255.0
# 28           2    19            D 1990-10-31      F     2621.0
# 29           2    19            V 1991-01-31      F     2816.0
# 30           1    15            T 1990-11-30      M     2979.0
# 31           1     9            H 1991-02-28      M     2901.0
# 32           1     8            B 1991-04-30      M     2013.0
# 33           2     5            C 1991-06-30      F     2472.0
# 34           1     7            K 1991-07-31      F     2494.0
# 35           4     6            B 1991-08-31      F     2320.0

# %%
a = df1.merge(df2, on=["CNIC","Account No"], how="right")
a
# Out:
#     Account No  CNIC CustomerName        DOB Gender  Mobile No
# 0            4     2            J 1990-12-31      M       2690
# 1            4    13            Y 1990-05-31      M       2281
# 2            1    19            X 1990-01-31      M       2812
# 3            2    13            N 1990-09-30      F       2421
# 4            2    13            P 1991-03-31      M       2391
# 5            4    15            B 1990-02-28      M       2414
# 6            4    14            T 1990-03-31      M       2732
# 7            3    16            A 1990-04-30      F       2425
# 8            3    16            R 1991-05-31      M       2029
# 9            2    18            I 1990-06-30      M       2591
# 10           1     3            A 1990-07-31      F       2557
# 11           4    19            W 1990-08-31      F       2255
# 12           2    19            D 1990-10-31      F       2621
# 13           2    19            V 1991-01-31      F       2816
# 14           1    15            T 1990-11-30      M       2979
# 15           1     9            H 1991-02-28      M       2901
# 16           1     8            B 1991-04-30      M       2013
# 17           2     5            C 1991-06-30      F       2472
# 18           1     7            K 1991-07-31      F       2494
# 19           4     6            B 1991-08-31      F       2320

# %%
df1.columns
df1.columns = ['Customer CNIC', 'Customer Account No']
df1.head(1)
# Out:
#    Customer CNIC  Customer Account No
# 0              2                    6

# %%
df2.columns 
df2.head()
# Out:
#    Account No  CNIC CustomerName        DOB Gender  Mobile No
# 0           1    19            X 1990-01-31      M       2812
# 1           4    15            B 1990-02-28      M       2414
# 2           4    14            T 1990-03-31      M       2732
# 3           3    16            A 1990-04-30      F       2425
# 4           4    13            Y 1990-05-31      M       2281

# %% [markdown]
# # data_frame_left.merge(dataframe_right, left_on="col", right_on="col", how="typeofJoin")

# %%
a = df1.merge(df2, left_on="Customer CNIC", right_on="CNIC")
a
# Out:
#     Customer CNIC  Customer Account No  Account No  CNIC CustomerName  \
# 0               2                    6           4     2            J
# 1               2                    9           4     2            J
# 2               2                   11           4     2            J
# 3               2                    7           4     2            J
# 4               2                    6           4     2            J
# 5               2                   17           4     2            J
# 6               2                   14           4     2            J
# 7               2                    6           4     2            J
# 8               2                   13           4     2            J
# 9               2                    2           4     2            J
# 10              3                   14           1     3            A
# 11              3                   14           1     3            A
#
#           DOB Gender  Mobile No
# 0  1990-12-31      M       2690
# 1  1990-12-31      M       2690
# 2  1990-12-31      M       2690
# 3  1990-12-31      M       2690
# 4  1990-12-31      M       2690
# 5  1990-12-31      M       2690
# 6  1990-12-31      M       2690
# 7  1990-12-31      M       2690
# 8  1990-12-31      M       2690
# 9  1990-12-31      M       2690
# 10 1990-07-31      F       2557
# 11 1990-07-31      F       2557

# %%
a = df1.merge(df2, left_on=["Customer CNIC","Customer Account No"], right_on=["CNIC","Account No"])
a
# Out:
# Empty DataFrame
# Columns: [Customer CNIC, Customer Account No, Account No, CNIC, CustomerName, DOB, Gender, Mobile No]
# Index: []

# %% [markdown]
# # Join with Index

# %%
customers = pd.DataFrame({"Customers NIC": [14,6,19],"Customer Name":["A","B","C"]})


transactions = pd.DataFrame({"CNIC": np.random.choice([14,6,19,21], size=(20)),
                   "TransactionID":np.random.randint(1,2, size=(20)),
                  "Transaction Date":pd.date_range('1990-01-01', periods=20),
                   "Description":np.random.choice(["M","F"], size=(20))})


customers
# Out:
#   Customer Name  Customers NIC
# 0             A             14
# 1             B              6
# 2             C             19

# %%
transactions
# Out:
#     CNIC Description Transaction Date  TransactionID
# 0      6           F       1990-01-01              1
# 1     19           M       1990-01-02              1
# 2     19           M       1990-01-03              1
# 3     19           F       1990-01-04              1
# 4     19           M       1990-01-05              1
# 5     21           M       1990-01-06              1
# 6     14           F       1990-01-07              1
# 7     21           F       1990-01-08              1
# 8     19           M       1990-01-09              1
# 9     21           F       1990-01-10              1
# 10    14           F       1990-01-11              1
# 11    14           M       1990-01-12              1
# 12    21           M       1990-01-13              1
# 13     6           M       1990-01-14              1
# 14    19           M       1990-01-15              1
# 15    21           M       1990-01-16              1
# 16    21           F       1990-01-17              1
# 17    21           F       1990-01-18              1
# 18    21           M       1990-01-19              1
# 19     6           M       1990-01-20              1

# %%
c = transactions.CNIC.value_counts()
c
# Out:
# 21    8
# 19    6
# 14    3
# 6     3
# Name: CNIC, dtype: int64

# %%
a = customers.merge(c, left_on="Customers NIC", right_index=True)
a.columns = ['Customers NIC', 'Customer Name', 'Tr counts']
a
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-ef0c0e4b2fc1> in <module>()
# ----> 1 a = customers.merge(c, left_on="Customers NIC", right_index=True)
#       2 a.columns = ['Customers NIC', 'Customer Name', 'Tr counts']
#       3 a
#
# C:\Users\Hp\Anaconda3\lib\site-packages\pandas\core\frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator)
#    4605                      right_on=right_on, left_index=left_index,
#    4606                      right_index=right_index, sort=sort, suffixes=suffixes,
# -> 4607                      copy=copy, indicator=indicator)
#    4608
#    4609     def round(self, decimals=0, *args, **kwargs):
#
# C:\Users\Hp\Anaconda3\lib\site-packages\pandas\tools\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator)
#      59                          right_on=right_on, left_index=left_index,
#      60                          right_index=right_index, sort=sort, suffixes=suffixes,
# ---> 61                          copy=copy, indicator=indicator)
#      62     return op.get_result()
#      63 if __debug__:
#
# C:\Users\Hp\Anaconda3\lib\site-packages\pandas\tools\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator)
#     518             raise ValueError(
#     519                 'can not merge DataFrame with instance of '
# --> 520                 'type {0}'.format(type(right)))
#     521
#     522         if not is_bool(left_index):
#
# ValueError: can not merge DataFrame with instance of type <class 'pandas.core.series.Series'>

# %%
df1 = pd.DataFrame({"CNIC": [1,2],
                   "Account No":np.random.randint(1,2, size=(2))})


df2 = pd.DataFrame({"CNIC": np.random.randint(1,20, size=(20)),
                   "Account No":np.random.randint(1,2, size=(20)),
                   "Mobile No":np.random.randint(2001,3000, size=(20)),
                  "DOB":pd.date_range('1990-01-01', periods=20),
                  "CustomerName":[chr(x) for x in np.random.randint(65,91, size=(20))],
                   "Gender":np.random.choice(["M","F"], size=(20))})
a = df1.join(df2, on="CNIC", how='left', lsuffix='_customer', rsuffix='_portfoli')
a

# %%
customers = pd.DataFrame({"Customers NIC": [14,6,19],"Customer Name":["A","B","C"]})


transactions = pd.DataFrame({"CNIC": np.random.choice([14,6,19,21], size=(20)),
                   "TransactionID":np.random.randint(1,2, size=(20)),
                  "Transaction Date":pd.date_range('1990-01-01', periods=20, freq='Y'),
                   "Description":np.random.choice(["M","F"], size=(20)),
                            "Actual Amount":np.random.randint(1,10000, size=(20))})


transactions.columns = ['CNIC', 'TransactionID', 'Transaction Date', 'Gender','Actual Amount']
transactions

# %% [markdown]
# # Group By

# %%
#dataframeName.groupby(by="").agg([count,min,max])
#dataframeName.groupby(by=[col1,col2,..]).agg([count,min,max])

c = transactions.groupby("Gender").agg(['count'])
c

# %%
# %timeit c = transactions.groupby("Gender")[["CNIC"]].agg(['count'])
# %timeit c

# %%
c = transactions.groupby([transactions['Transaction Date'].dt.year  ,  "Gender"])[["CNIC"]].agg(['count'])
c

# %%
c = transactions.groupby(["Gender","CNIC"])[["Actual Amount"]].agg(['count',"sum",'min','max'])
c

# %% [markdown]
# # df.ColumnName.cut()

# %%
pd.cut(transactions["Actual Amount"], 4).value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\Hp\Anaconda3\lib\site-packages\pandas\indexes\base.py in get_loc(self, key, method, tolerance)
#    2133             try:
# -> 2134                 return self._engine.get_loc(key)
#    2135             except KeyError:
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4433)()
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4279)()
#
# pandas\src\hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:13742)()
#
# pandas\src\hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:13696)()
#
# KeyError: 'Actual Amount'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-fafe8bd66e54> in <module>()
# ----> 1 pd.cut(transactions["Actual Amount"], 4).value_counts()
#
# C:\Users\Hp\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2057             return self._getitem_multilevel(key)
#    2058         else:
# -> 2059             return self._getitem_column(key)
#    2060
#    2061     def _getitem_column(self, key):
#
# C:\Users\Hp\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2064         # get column
#    2065         if self.columns.is_unique:
# -> 2066             return self._get_item_cache(key)
#    2067
#    2068         # duplicate columns & possible reduce dimensionality
#
# C:\Users\Hp\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    1384         res = cache.get(item)
#    1385         if res is None:
# -> 1386             values = self._data.get(item)
#    1387             res = self._box_item_values(item, values)
#    1388             cache[item] = res
#
# C:\Users\Hp\Anaconda3\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    3541
#    3542             if not isnull(item):
# -> 3543                 loc = self.items.get_loc(item)
#    3544             else:
#    3545                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# C:\Users\Hp\Anaconda3\lib\site-packages\pandas\indexes\base.py in get_loc(self, key, method, tolerance)
#    2134                 return self._engine.get_loc(key)
#    2135             except KeyError:
# -> 2136                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2137
#    2138         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4433)()
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4279)()
#
# pandas\src\hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:13742)()
#
# pandas\src\hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:13696)()
#
# KeyError: 'Actual Amount'

# %%
pd.cut(transactions["Actual Amount"], [1, 1000, 5000, 7000, 100000]).value_counts()

# %%
pd.qcut(transactions["Actual Amount"], [.0, .50, .8, 1]).value_counts()
